# %%
import pathlib
import pandas as pd
import numpy as np

from joblib import load

# Set the seed
rng = np.random.default_rng(0)

# %%
def shuffle_data(df):
    """
    Shuffle the feature columns of the input dataframe independently while keeping metadata columns unchanged.
    Columns with 'Metadata' prefix are considered metadata.

    Parameters
    ----------
    df : pandas.DataFrame
        Input dataframe containing both features and metadata.
    """
    feature_columns = [col for col in df.columns if not col.startswith('Metadata')]

    shuffled_df = df.copy()
    
    for column in feature_columns:
        shuffled_df[column] = rng.permutation(shuffled_df[column])
    
    return shuffled_df

# %%
# Path to encoder
le_path = pathlib.Path("./data/trained_nf1_model_label_encoder.joblib")

# Path to model
model_path = pathlib.Path("./data/trained_nf1_model.joblib")

# Load in encoder
le = load(le_path)

# Load in NF1 model
model = load(model_path)

# %%
# Load in the model data
model_df = pd.read_parquet(pathlib.Path("./model_data.parquet"))

meta_cols = model_df.filter(like="Metadata").columns

print(model_df.shape)
model_df.head()
# Out:
# (21370, 870)
#    Nuclei_RadialDistribution_ZernikeMagnitude_GFP_8_6  \
# 0                                          -1.063849
# 1                                          -0.969352
# 2                                          -0.083428
# 3                                           1.919927
# 4                                           0.184429
#
#    Nuclei_AreaShape_Zernike_7_1  \
# 0                      1.479502
# 1                     -0.754828
# 2                      1.610322
# 3                     -0.853120
# 4                      0.403966
#
#    Cells_RadialDistribution_ZernikeMagnitude_RFP_6_0  \
# 0                                          -0.479305
# 1                                           0.317790
# 2                                           0.319736
# 3                                           3.963571
# 4                                           0.313153
#
#    Nuclei_RadialDistribution_ZernikeMagnitude_DAPI_5_5  \
# 0                                          -0.093464
# 1                                           0.312964
# 2                                          -0.172855
# 3                                          -1.031434
# 4                                           0.054143
#
#    Nuclei_RadialDistribution_ZernikePhase_GFP_9_1  \
# 0                                        1.440293
# 1                                       -1.542194
# 2                                       -0.288915
# 3                                       -1.399657
# 4                                       -0.898072
#
#    Nuclei_Texture_Correlation_GFP_3_01_256  \
# 0                                 0.878041
# 1                                 1.401663
# 2                                 0.159513
# 3                                -0.282898
# 4                                -0.609744
#
#    Cytoplasm_RadialDistribution_ZernikeMagnitude_CY5_3_3  \
# 0                                           0.518878
# 1                                           0.797627
# 2                                          -0.024944
# 3                                          -0.164698
# 4                                          -0.309397
#
#    Nuclei_Texture_Correlation_DAPI_3_02_256  \
# 0                                 -1.007931
# 1                                  0.128219
# 2                                 -1.034824
# 3                                  0.098882
# 4                                  0.203530
#
#    Cells_Intensity_MADIntensity_DAPI  \
# 0                          -0.460367
# 1                           1.412492
# 2                          -0.103696
# 3                          -0.303052
# 4                          -0.148450
#
#    Cytoplasm_RadialDistribution_MeanFrac_RFP_3of4  ...  \
# 0                                        0.843777  ...
# 1                                        0.187499  ...
# 2                                        0.787885  ...
# 3                                        0.472728  ...
# 4                                       -1.693646  ...
#
#    Nuclei_RadialDistribution_FracAtD_CY5_4of4  \
# 0                                    0.213263
# 1                                   -2.097610
# 2                                   -1.104407
# 3                                    0.494178
# 4                                   -0.016520
#
#    Cells_RadialDistribution_ZernikePhase_DAPI_9_5  \
# 0                                        0.230531
# 1                                       -1.229214
# 2                                       -0.961465
# 3                                        0.892562
# 4                                        0.024378
#
#    Cytoplasm_AreaShape_Zernike_8_4  \
# 0                        -0.845320
# 1                         0.379174
# 2                        -1.543201
# 3                         0.872675
# 4                         0.824451
#
#    Cells_RadialDistribution_FracAtD_DAPI_3of4  \
# 0                                   -2.026702
# 1                                    0.464392
# 2                                    0.880911
# 3                                   -0.045790
# 4                                    0.109087
#
#    Cytoplasm_Correlation_RWC_DAPI_CY5  \
# 0                            0.270841
# 1                            0.734386
# 2                            0.873302
# 3                           -0.935511
# 4                            0.035524
#
#    Nuclei_RadialDistribution_ZernikeMagnitude_CY5_9_7  \
# 0                                          -0.762607
# 1                                           0.456039
# 2                                           0.038485
# 3                                           0.065476
# 4                                          -0.197065
#
#    Cytoplasm_RadialDistribution_ZernikePhase_CY5_7_1  \
# 0                                          -0.160670
# 1                                          -1.063727
# 2                                           1.412895
# 3                                           1.319694
# 4                                           0.360104
#
#    Nuclei_Texture_InfoMeas2_RFP_3_03_256  Cytoplasm_AreaShape_Zernike_4_0  \
# 0                              -2.915689                        -1.243646
# 1                               0.016138                        -0.626757
# 2                               1.096584                         1.128840
# 3                               0.932735                         0.099949
# 4                              -0.753957                         0.245045
#
#    Metadata_datasplit
# 0                rest
# 1                rest
# 2                rest
# 3                rest
# 4                rest
#
# [5 rows x 870 columns]

# %%
# Decode the true genotypes using the encoder
true_genotypes = le.fit_transform(model_df["Metadata_genotype"])

probabilitydf = pd.DataFrame(
    {
        f"probability_{le.inverse_transform([1])[0]}": model.predict_proba(model_df[model.feature_names_in_])[:, 1],
        "predicted_genotype": model.predict(model_df[model.feature_names_in_]),
        "true_genotype": true_genotypes
    }
)

probabilitydf = pd.concat([probabilitydf, model_df[meta_cols].reset_index(drop=True)], axis=1)

# Rename 'Metadata_datasplit' to 'datasplit'
probabilitydf.rename(columns={'Metadata_datasplit': 'datasplit'}, inplace=True)

# Move 'datasplit' to the start of the DataFrame
cols = ['datasplit'] + [col for col in probabilitydf if col != 'datasplit']
probabilitydf = probabilitydf[cols]

print(probabilitydf.shape)
probabilitydf.head()
# Out:
# (21370, 21)
#   datasplit  probability_WT  predicted_genotype  true_genotype  \
# 0      rest        0.127298                   0              0
# 1      rest        0.086884                   0              0
# 2      rest        0.634054                   1              0
# 3      rest        0.003741                   0              0
# 4      rest        0.161921                   0              0
#
#    Metadata_Cells_Number_Object_Number  Metadata_ImageNumber  \
# 0                                  2.0                1177.0
# 1                                  5.0                  32.0
# 2                                  1.0                 290.0
# 3                                  9.0                1016.0
# 4                                  7.0                 534.0
#
#    Metadata_Cells_Location_Center_Y  Metadata_Nuclei_Number_Object_Number  \
# 0                        317.145584                                   3.0
# 1                        318.523005                                   6.0
# 2                        564.884298                                   1.0
# 3                        713.809386                                   9.0
# 4                        551.984447                                   9.0
#
#   Metadata_WellRow  Metadata_Cytoplasm_Parent_Nuclei  ...  \
# 0                F                               3.0  ...
# 1                B                               6.0  ...
# 2                C                               1.0  ...
# 3                F                               9.0  ...
# 4                D                               9.0  ...
#
#   Metadata_number_of_singlecells  Metadata_WellCol  Metadata_Plate  \
# 0                            149                 9         Plate_5
# 1                            148                11         Plate_5
# 2                            119                12         Plate_5
# 3                            125                12         Plate_5
# 4                            106                12         Plate_5
#
#   Metadata_Nuclei_Location_Center_Y  Metadata_Well  \
# 0                        356.292837             F9
# 1                        311.350248            B11
# 2                        556.116579            C12
# 3                        700.850537            F12
# 4                        582.018333            D12
#
#   Metadata_Cells_Location_Center_X  Metadata_Nuclei_Location_Center_X  \
# 0                       875.270222                         902.972299
# 1                       606.513594                         615.165938
# 2                       345.700749                         394.213240
# 3                       276.998649                         288.714100
# 4                       924.846837                         947.446667
#
#    Metadata_Site Metadata_gene_name Metadata_Cytoplasm_Parent_Cells
# 0             14                NF1                             2.0
# 1              1                NF1                             5.0
# 2             17                NF1                             1.0
# 3              6                NF1                             9.0
# 4             16                NF1                             7.0
#
# [5 rows x 21 columns]

# %%
probabilitydf["Metadata_Plate"].unique()
# Out:
# array(['Plate_5', 'Plate_3', 'Plate_3_prime', 'Plate_4'], dtype=object)

# %% [markdown]
# ## Shuffle the data and apply model

# %%
model_shuffled_df = shuffle_data(model_df)

meta_cols = model_shuffled_df.filter(like="Metadata").columns

model_shuffled_df['Metadata_datasplit'] = 'shuffled_' + model_shuffled_df['Metadata_datasplit'].astype(str)

print(model_shuffled_df.shape)
model_shuffled_df.head()
# Out:
# (21370, 870)
#    Nuclei_RadialDistribution_ZernikeMagnitude_GFP_8_6  \
# 0                                          -0.725787
# 1                                          -0.030691
# 2                                          -0.411171
# 3                                          -0.502580
# 4                                           0.521748
#
#    Nuclei_AreaShape_Zernike_7_1  \
# 0                     -0.051563
# 1                     -1.252319
# 2                      2.454155
# 3                      1.147165
# 4                      0.413192
#
#    Cells_RadialDistribution_ZernikeMagnitude_RFP_6_0  \
# 0                                           0.077541
# 1                                           0.918384
# 2                                          -0.317497
# 3                                           0.140886
# 4                                           1.381932
#
#    Nuclei_RadialDistribution_ZernikeMagnitude_DAPI_5_5  \
# 0                                           0.388280
# 1                                          -0.486414
# 2                                           6.920159
# 3                                           0.767430
# 4                                           0.349153
#
#    Nuclei_RadialDistribution_ZernikePhase_GFP_9_1  \
# 0                                        0.937687
# 1                                       -1.248994
# 2                                       -0.195333
# 3                                        1.542222
# 4                                       -0.284557
#
#    Nuclei_Texture_Correlation_GFP_3_01_256  \
# 0                                 0.692581
# 1                                 1.091782
# 2                                 0.080899
# 3                                -1.484568
# 4                                 0.438640
#
#    Cytoplasm_RadialDistribution_ZernikeMagnitude_CY5_3_3  \
# 0                                          -0.189219
# 1                                          -0.789636
# 2                                          -0.420834
# 3                                          -0.207952
# 4                                          -0.678318
#
#    Nuclei_Texture_Correlation_DAPI_3_02_256  \
# 0                                 -0.541059
# 1                                  1.090820
# 2                                 -1.126813
# 3                                 -2.558360
# 4                                 -1.243163
#
#    Cells_Intensity_MADIntensity_DAPI  \
# 0                          -0.438668
# 1                          -0.161649
# 2                          -0.229401
# 3                          -0.136000
# 4                          -0.248275
#
#    Cytoplasm_RadialDistribution_MeanFrac_RFP_3of4  ...  \
# 0                                        0.175209  ...
# 1                                        0.235242  ...
# 2                                        0.445625  ...
# 3                                       -0.559237  ...
# 4                                        0.548753  ...
#
#    Nuclei_RadialDistribution_FracAtD_CY5_4of4  \
# 0                                    0.714301
# 1                                   -0.440515
# 2                                    0.058922
# 3                                   -0.029330
# 4                                   -0.937562
#
#    Cells_RadialDistribution_ZernikePhase_DAPI_9_5  \
# 0                                       -0.565112
# 1                                       -1.148477
# 2                                       -1.537658
# 3                                       -1.496945
# 4                                        1.358233
#
#    Cytoplasm_AreaShape_Zernike_8_4  \
# 0                         0.028403
# 1                        -0.428054
# 2                         1.752856
# 3                         0.316757
# 4                         0.700310
#
#    Cells_RadialDistribution_FracAtD_DAPI_3of4  \
# 0                                    0.323530
# 1                                   -0.313825
# 2                                   -0.273968
# 3                                   -2.938778
# 4                                   -1.040630
#
#    Cytoplasm_Correlation_RWC_DAPI_CY5  \
# 0                            0.009417
# 1                            0.577278
# 2                           -0.015247
# 3                           -1.145859
# 4                           -0.958120
#
#    Nuclei_RadialDistribution_ZernikeMagnitude_CY5_9_7  \
# 0                                           2.637656
# 1                                          -0.730832
# 2                                          -0.499259
# 3                                          -0.196487
# 4                                          -0.293880
#
#    Cytoplasm_RadialDistribution_ZernikePhase_CY5_7_1  \
# 0                                           0.314585
# 1                                          -0.925885
# 2                                           1.441778
# 3                                           0.625010
# 4                                          -0.909364
#
#    Nuclei_Texture_InfoMeas2_RFP_3_03_256  Cytoplasm_AreaShape_Zernike_4_0  \
# 0                              -0.800461                         4.510781
# 1                              -0.018684                        -0.439678
# 2                               0.181854                         0.819933
# 3                               0.891056                        -1.143550
# 4                              -0.130199                        -0.954818
#
#    Metadata_datasplit
# 0       shuffled_rest
# 1       shuffled_rest
# 2       shuffled_rest
# 3       shuffled_rest
# 4       shuffled_rest
#
# [5 rows x 870 columns]

# %%
# Decode the true genotypes using the encoder
true_genotypes = le.fit_transform(model_shuffled_df["Metadata_genotype"])

shuffled_probabilitydf = pd.DataFrame(
    {
        f"probability_{le.inverse_transform([1])[0]}": model.predict_proba(model_shuffled_df[model.feature_names_in_])[:, 1],
        "predicted_genotype": model.predict(model_shuffled_df[model.feature_names_in_]),
        "true_genotype": true_genotypes
    }
)

shuffled_probabilitydf = pd.concat([shuffled_probabilitydf, model_shuffled_df[meta_cols].reset_index(drop=True)], axis=1)

# Rename 'Metadata_datasplit' to 'datasplit'
shuffled_probabilitydf.rename(columns={'Metadata_datasplit': 'datasplit'}, inplace=True)

# Move 'datasplit' to the start of the DataFrame
cols = ['datasplit'] + [col for col in shuffled_probabilitydf if col != 'datasplit']
shuffled_probabilitydf = shuffled_probabilitydf[cols]

print(shuffled_probabilitydf.shape)
shuffled_probabilitydf.head()
# Out:
# (21370, 21)
#        datasplit  probability_WT  predicted_genotype  true_genotype  \
# 0  shuffled_rest        0.865907                   1              0
# 1  shuffled_rest        0.006202                   0              0
# 2  shuffled_rest        0.303340                   0              0
# 3  shuffled_rest        0.039801                   0              0
# 4  shuffled_rest        0.057411                   0              0
#
#    Metadata_Cells_Number_Object_Number  Metadata_ImageNumber  \
# 0                                  2.0                1177.0
# 1                                  5.0                  32.0
# 2                                  1.0                 290.0
# 3                                  9.0                1016.0
# 4                                  7.0                 534.0
#
#    Metadata_Cells_Location_Center_Y  Metadata_Nuclei_Number_Object_Number  \
# 0                        317.145584                                   3.0
# 1                        318.523005                                   6.0
# 2                        564.884298                                   1.0
# 3                        713.809386                                   9.0
# 4                        551.984447                                   9.0
#
#   Metadata_WellRow  Metadata_Cytoplasm_Parent_Nuclei  ...  \
# 0                F                               3.0  ...
# 1                B                               6.0  ...
# 2                C                               1.0  ...
# 3                F                               9.0  ...
# 4                D                               9.0  ...
#
#   Metadata_number_of_singlecells  Metadata_WellCol  Metadata_Plate  \
# 0                            149                 9         Plate_5
# 1                            148                11         Plate_5
# 2                            119                12         Plate_5
# 3                            125                12         Plate_5
# 4                            106                12         Plate_5
#
#   Metadata_Nuclei_Location_Center_Y  Metadata_Well  \
# 0                        356.292837             F9
# 1                        311.350248            B11
# 2                        556.116579            C12
# 3                        700.850537            F12
# 4                        582.018333            D12
#
#   Metadata_Cells_Location_Center_X  Metadata_Nuclei_Location_Center_X  \
# 0                       875.270222                         902.972299
# 1                       606.513594                         615.165938
# 2                       345.700749                         394.213240
# 3                       276.998649                         288.714100
# 4                       924.846837                         947.446667
#
#    Metadata_Site Metadata_gene_name Metadata_Cytoplasm_Parent_Cells
# 0             14                NF1                             2.0
# 1              1                NF1                             5.0
# 2             17                NF1                             1.0
# 3              6                NF1                             9.0
# 4             16                NF1                             7.0
#
# [5 rows x 21 columns]

# %%
# Concatenate the DataFrames vertically and save to a Parquet file
combined_df = pd.concat([shuffled_probabilitydf, probabilitydf], axis=0).reset_index(drop=True)
combined_df.to_parquet(f"./data/nf1_eval_data.parquet")

combined_df
# Out:
#            datasplit  probability_WT  predicted_genotype  true_genotype  \
# 0      shuffled_rest        0.865907                   1              0
# 1      shuffled_rest        0.006202                   0              0
# 2      shuffled_rest        0.303340                   0              0
# 3      shuffled_rest        0.039801                   0              0
# 4      shuffled_rest        0.057411                   0              0
# ...              ...             ...                 ...            ...
# 42735           test        0.544581                   1              1
# 42736           test        0.975218                   1              1
# 42737           test        0.347940                   0              1
# 42738           test        0.957261                   1              1
# 42739           test        0.777984                   1              1
#
#        Metadata_Cells_Number_Object_Number  Metadata_ImageNumber  \
# 0                                      2.0                1177.0
# 1                                      5.0                  32.0
# 2                                      1.0                 290.0
# 3                                      9.0                1016.0
# 4                                      7.0                 534.0
# ...                                    ...                   ...
# 42735                                  3.0                 288.0
# 42736                                  3.0                 270.0
# 42737                                  3.0                 265.0
# 42738                                  2.0                 277.0
# 42739                                  9.0                 271.0
#
#        Metadata_Cells_Location_Center_Y  Metadata_Nuclei_Number_Object_Number  \
# 0                            317.145584                                   3.0
# 1                            318.523005                                   6.0
# 2                            564.884298                                   1.0
# 3                            713.809386                                   9.0
# 4                            551.984447                                   9.0
# ...                                 ...                                   ...
# 42735                        358.720822                                   4.0
# 42736                        669.784779                                   5.0
# 42737                        251.700852                                   5.0
# 42738                        226.483731                                   2.0
# 42739                        700.874390                                  10.0
#
#       Metadata_WellRow  Metadata_Cytoplasm_Parent_Nuclei  ...  \
# 0                    F                               3.0  ...
# 1                    B                               6.0  ...
# 2                    C                               1.0  ...
# 3                    F                               9.0  ...
# 4                    D                               9.0  ...
# ...                ...                               ...  ...
# 42735                C                               4.0  ...
# 42736                C                               5.0  ...
# 42737                C                               5.0  ...
# 42738                C                               2.0  ...
# 42739                C                              10.0  ...
#
#       Metadata_number_of_singlecells  Metadata_WellCol  Metadata_Plate  \
# 0                                149                 9         Plate_5
# 1                                148                11         Plate_5
# 2                                119                12         Plate_5
# 3                                125                12         Plate_5
# 4                                106                12         Plate_5
# ...                              ...               ...             ...
# 42735                             95                11         Plate_4
# 42736                             95                11         Plate_4
# 42737                             95                11         Plate_4
# 42738                             95                11         Plate_4
# 42739                             95                11         Plate_4
#
#       Metadata_Nuclei_Location_Center_Y  Metadata_Well  \
# 0                            356.292837             F9
# 1                            311.350248            B11
# 2                            556.116579            C12
# 3                            700.850537            F12
# 4                            582.018333            D12
# ...                                 ...            ...
# 42735                        376.879008            C11
# 42736                        647.613644            C11
# 42737                        221.622005            C11
# 42738                        279.212354            C11
# 42739                        690.122222            C11
#
#       Metadata_Cells_Location_Center_X  Metadata_Nuclei_Location_Center_X  \
# 0                           875.270222                         902.972299
# 1                           606.513594                         615.165938
# 2                           345.700749                         394.213240
# 3                           276.998649                         288.714100
# 4                           924.846837                         947.446667
# ...                                ...                                ...
# 42735                       708.548012                         699.588793
# 42736                       160.533679                         137.917724
# 42737                       563.757778                         543.670216
# 42738                       941.952479                         898.655336
# 42739                       595.927172                         589.717417
#
#        Metadata_Site Metadata_gene_name Metadata_Cytoplasm_Parent_Cells
# 0                 14                NF1                             2.0
# 1                  1                NF1                             5.0
# 2                 17                NF1                             1.0
# 3                  6                NF1                             9.0
# 4                 16                NF1                             7.0
# ...              ...                ...                             ...
# 42735              9                NF1                             3.0
# 42736             16                NF1                             3.0
# 42737             11                NF1                             3.0
# 42738             22                NF1                             2.0
# 42739             17                NF1                             9.0
#
# [42740 rows x 21 columns]
