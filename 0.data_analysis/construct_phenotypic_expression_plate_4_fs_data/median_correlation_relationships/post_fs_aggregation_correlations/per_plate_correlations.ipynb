# %%
import pandas as pd
import pathlib
import numpy as np

# %%
# Get the current working directory
cwd = pathlib.Path.cwd()

if (cwd / ".git").is_dir():
    root_dir = cwd

else:
    root_dir = None
    for parent in cwd.parents:
        if (parent / ".git").is_dir():
            root_dir = parent
            break

# Check if a Git root directory was found
if root_dir is None:
    raise FileNotFoundError("No Git root directory found.")

# %% [markdown]
# ## Function for pairwise correlations

# %%
def generate_correlations(df, feat_cols):
    # Copy df so that data is not lost
    df_corr = df.copy()

    # Generate Pearson correlations between all wells
    correlations = df_corr.loc[:, feat_cols].transpose().corr(method='pearson')

    # Remove the lower triangle
    correlations = correlations.where(np.triu(np.ones(correlations.shape), k=1).astype(bool))

    # Flip, reset index, and add column names
    correlations = correlations.stack().reset_index()
    correlations.columns = ['group0_index', 'group1_index', 'correlation']

    # Map index to corresponding Metadata_Well__group
    correlations['Metadata_Well__group0'] = df.loc[correlations['group0_index'], 'Metadata_Well'].values
    correlations['Metadata_Well__group1'] = df.loc[correlations['group1_index'], 'Metadata_Well'].values

    correlations['Metadata_genotype__group0'] = df.loc[correlations['group0_index'], 'Metadata_genotype'].values
    correlations['Metadata_genotype__group1'] = df.loc[correlations['group1_index'], 'Metadata_genotype'].values

    # Map index to Metadata_plate
    correlations['Metadata_plate__group0'] = df.loc[correlations['group0_index'], 'Metadata_Plate'].values
    correlations['Metadata_plate__group1'] = df.loc[correlations['group1_index'], 'Metadata_Plate'].values

    # Conditionally include Metadata_seed_density
    if 'Metadata_seed_density' in df.columns:
        correlations['Metadata_seed_density__group0'] = df.loc[correlations['group0_index'], 'Metadata_seed_density'].values
        correlations['Metadata_seed_density__group1'] = df.loc[correlations['group1_index'], 'Metadata_seed_density'].values
    else: # Default to 0 since the column has to be of the same type (can't be a str)
        correlations['Metadata_seed_density__group0'] = 0
        correlations['Metadata_seed_density__group1'] = 0

    # Drop the index columns
    correlations = correlations.drop(columns=['group0_index', 'group1_index'])

    return correlations

# %% [markdown]
# ## Load in data and compute correlations per well

# %% [markdown]
# ### Plate 4 only controls

# %%
# Load in plate 4 dataframe (only controls)
plate4_path = pathlib.Path(f"{root_dir}/../nf1_cellpainting_data/3.processing_features/data/single_cell_profiles/Plate_4_bulk_camerons_method.parquet")
plate4df = pd.read_parquet(plate4_path)
# Fill missing values in Metadata_siRNA column with 'No Construct'
plate4df['Metadata_siRNA'] = plate4df['Metadata_siRNA'].fillna('No Construct')
# Only include rows where Metadata_siRNA contains 'No Construct'
plate4df = plate4df[plate4df['Metadata_siRNA'].str.contains('No Construct')]

print(plate4df.shape)
plate4df.head()
# Out:
# (15, 1153)
#    Metadata_WellRow  Metadata_WellCol Metadata_Well  \
# 0                 B                 2            B2
# 3                 B                 5            B5
# 6                 B                 8            B8
# 9                 B                11           B11
# 10                C                 2            C2
#
#     Metadata_number_of_singlecells Metadata_gene_name Metadata_genotype  \
# 0                              111                NF1                WT
# 3                              124                NF1                WT
# 6                              125                NF1                WT
# 9                              101                NF1                WT
# 10                             140                NF1              Null
#
#     Metadata_seed_density Metadata_siRNA  Metadata_RNAiMax  \
# 0                    1000   No Construct                 0
# 3                    1000   No Construct                 0
# 6                    1000   No Construct                 0
# 9                    1000   No Construct                 1
# 10                   1000   No Construct                 0
#
#     Metadata_Concentration  ...  \
# 0                      0.0  ...
# 3                      0.0  ...
# 6                      0.0  ...
# 9                      0.0  ...
# 10                     0.0  ...
#
#    Nuclei_Texture_InverseDifferenceMoment_RFP_3_00_256  \
# 0                                           -0.495849
# 3                                           -0.172880
# 6                                           -0.273476
# 9                                           -0.064904
# 10                                          -0.134203
#
#     Nuclei_Texture_InverseDifferenceMoment_RFP_3_01_256  \
# 0                                           -0.497374
# 3                                           -0.233792
# 6                                           -0.227579
# 9                                           -0.131255
# 10                                           0.000661
#
#     Nuclei_Texture_InverseDifferenceMoment_RFP_3_02_256  \
# 0                                           -0.519248
# 3                                           -0.229009
# 6                                           -0.272331
# 9                                           -0.002931
# 10                                           0.083006
#
#     Nuclei_Texture_InverseDifferenceMoment_RFP_3_03_256  \
# 0                                           -0.494432
# 3                                           -0.233701
# 6                                           -0.303979
# 9                                           -0.031453
# 10                                           0.069496
#
#     Nuclei_Texture_SumEntropy_DAPI_3_03_256  \
# 0                                  0.195967
# 3                                  0.203310
# 6                                  0.359007
# 9                                  0.264286
# 10                                 0.216541
#
#     Nuclei_Texture_SumEntropy_RFP_3_00_256  \
# 0                                 0.539823
# 3                                 0.026878
# 6                                 0.097057
# 9                                 0.019452
# 10                               -0.214588
#
#     Nuclei_Texture_SumVariance_CY5_3_01_256  \
# 0                                 -0.425107
# 3                                 -0.265577
# 6                                 -0.400673
# 9                                 -0.242469
# 10                                -0.402276
#
#     Nuclei_Texture_SumVariance_DAPI_3_01_256  \
# 0                                   0.020265
# 3                                  -0.019935
# 6                                   0.006489
# 9                                   0.003148
# 10                                 -0.242664
#
#     Nuclei_Texture_SumVariance_GFP_3_03_256  \
# 0                                 -0.314718
# 3                                 -0.373997
# 6                                 -0.277640
# 9                                 -0.305344
# 10                                -0.354394
#
#     Nuclei_Texture_SumVariance_RFP_3_01_256
# 0                                 -0.037639
# 3                                 -0.267422
# 6                                 -0.260283
# 9                                 -0.263122
# 10                                -0.432532
#
# [5 rows x 1153 columns]

# %% [markdown]
# ### Plate 3

# %%
# Load in plate 3 dataframe
plate3_path = pathlib.Path(f"{root_dir}/../nf1_cellpainting_data/3.processing_features/data/single_cell_profiles/Plate_3_bulk_camerons_method.parquet")
plate3df = pd.read_parquet(plate3_path)

print(plate3df.shape)
plate3df.head()
# Out:
# (48, 1161)
#   Metadata_WellRow  Metadata_WellCol Metadata_Well  \
# 0                B                 1            B1
# 1                B                 2            B2
# 2                B                 3            B3
# 3                B                 4            B4
# 4                B                 9            B9
#
#    Metadata_number_of_singlecells Metadata_gene_name Metadata_genotype  \
# 0                              45                NF1                WT
# 1                             139                NF1                WT
# 2                             297                NF1                WT
# 3                             559                NF1                WT
# 4                              71                NF1              Null
#
#    Metadata_seed_density Metadata_Plate  Cytoplasm_AreaShape_Compactness  \
# 0                    500        Plate_3                        -0.428712
# 1                   1000        Plate_3                        -0.394507
# 2                   2000        Plate_3                        -0.293458
# 3                   4000        Plate_3                         0.145103
# 4                    500        Plate_3                        -0.751483
#
#    Cytoplasm_AreaShape_Eccentricity  ...  \
# 0                          0.767925  ...
# 1                          0.398968  ...
# 2                          0.344648  ...
# 3                          0.114339  ...
# 4                          0.410983  ...
#
#    Nuclei_Texture_InverseDifferenceMoment_RFP_3_00_256  \
# 0                                          -0.854267
# 1                                          -0.152886
# 2                                          -0.040054
# 3                                          -0.414899
# 4                                          -0.455060
#
#    Nuclei_Texture_InverseDifferenceMoment_RFP_3_01_256  \
# 0                                          -0.880062
# 1                                          -0.178630
# 2                                          -0.027139
# 3                                          -0.346908
# 4                                          -0.400958
#
#    Nuclei_Texture_InverseDifferenceMoment_RFP_3_02_256  \
# 0                                          -0.599407
# 1                                          -0.072712
# 2                                           0.036813
# 3                                          -0.310155
# 4                                          -0.474513
#
#    Nuclei_Texture_InverseDifferenceMoment_RFP_3_03_256  \
# 0                                          -0.757853
# 1                                          -0.025244
# 2                                           0.169018
# 3                                          -0.211360
# 4                                          -0.415342
#
#    Nuclei_Texture_SumEntropy_DAPI_3_03_256  \
# 0                                 0.589546
# 1                                 0.313276
# 2                                -0.382035
# 3                                 0.256204
# 4                                 0.610320
#
#    Nuclei_Texture_SumEntropy_RFP_3_00_256  \
# 0                                0.985510
# 1                               -0.168541
# 2                               -0.266505
# 3                               -0.133034
# 4                                0.952098
#
#    Nuclei_Texture_SumVariance_CY5_3_01_256  \
# 0                                 0.466899
# 1                                -0.344835
# 2                                -0.441555
# 3                                -0.358743
# 4                                -0.051223
#
#    Nuclei_Texture_SumVariance_DAPI_3_03_256  \
# 0                                  0.147649
# 1                                 -0.300286
# 2                                 -0.777099
# 3                                 -0.147805
# 4                                  0.225277
#
#    Nuclei_Texture_SumVariance_GFP_3_01_256  \
# 0                                 0.526576
# 1                                -0.344560
# 2                                -0.409013
# 3                                -0.378605
# 4                                 1.029452
#
#    Nuclei_Texture_SumVariance_RFP_3_03_256
# 0                                 0.562450
# 1                                -0.370466
# 2                                -0.377588
# 3                                -0.351599
# 4                                 0.239045
#
# [5 rows x 1161 columns]

# %% [markdown]
# ### Plate 3 prime

# %%
# Load in plate 3 prime dataframe
plate3p_path = pathlib.Path(f"{root_dir}/../nf1_cellpainting_data/3.processing_features/data/single_cell_profiles/Plate_3_prime_bulk_camerons_method.parquet")
plate3pdf = pd.read_parquet(plate3p_path)

# Update Metadata_Plate for all rows
plate3pdf['Metadata_Plate'] = 'Plate_3_prime'

print(plate3pdf.shape)
plate3pdf.head()
# Out:
# (48, 1136)
#   Metadata_WellRow  Metadata_WellCol Metadata_Well  \
# 0                B                 1            B1
# 1                B                 2            B2
# 2                B                 3            B3
# 3                B                 4            B4
# 4                B                 9            B9
#
#    Metadata_number_of_singlecells Metadata_gene_name Metadata_genotype  \
# 0                              30                NF1                WT
# 1                              55                NF1                WT
# 2                              77                NF1                WT
# 3                             219                NF1                WT
# 4                              47                NF1              Null
#
#    Metadata_seed_density Metadata_Plate  Cytoplasm_AreaShape_Area  \
# 0                    500  Plate_3_prime                  0.655545
# 1                   1000  Plate_3_prime                  0.357419
# 2                   2000  Plate_3_prime                  0.405366
# 3                   4000  Plate_3_prime                  0.039740
# 4                    500  Plate_3_prime                  0.542509
#
#    Cytoplasm_AreaShape_BoundingBoxArea  ...  \
# 0                             0.543898  ...
# 1                             0.289749  ...
# 2                             0.292209  ...
# 3                            -0.055980  ...
# 4                             0.424221  ...
#
#    Nuclei_Texture_InverseDifferenceMoment_RFP_3_01_256  \
# 0                                          -0.041663
# 1                                          -0.245817
# 2                                          -0.491104
# 3                                          -0.141572
# 4                                          -0.059991
#
#    Nuclei_Texture_InverseDifferenceMoment_RFP_3_02_256  \
# 0                                          -0.162629
# 1                                          -0.118157
# 2                                          -0.398379
# 3                                          -0.292074
# 4                                           0.084494
#
#    Nuclei_Texture_InverseDifferenceMoment_RFP_3_03_256  \
# 0                                           0.297921
# 1                                          -0.364698
# 2                                          -0.148732
# 3                                          -0.185948
# 4                                          -0.175281
#
#    Nuclei_Texture_SumEntropy_CY5_3_02_256  \
# 0                               -0.984540
# 1                               -1.308534
# 2                                0.482892
# 3                                0.303884
# 4                               -0.484080
#
#    Nuclei_Texture_SumEntropy_DAPI_3_01_256  \
# 0                                 0.592404
# 1                                 0.359833
# 2                                -0.152515
# 3                                -0.126844
# 4                                 0.400114
#
#    Nuclei_Texture_SumEntropy_RFP_3_00_256  \
# 0                                0.038935
# 1                                0.462807
# 2                                0.204035
# 3                               -0.062962
# 4                                0.202381
#
#    Nuclei_Texture_SumVariance_CY5_3_03_256  \
# 0                                -0.586258
# 1                                -0.651352
# 2                                -0.074894
# 3                                -0.232299
# 4                                -0.431911
#
#    Nuclei_Texture_SumVariance_DAPI_3_03_256  \
# 0                                  0.471944
# 1                                 -0.001366
# 2                                 -0.564649
# 3                                 -0.626833
# 4                                  0.556435
#
#    Nuclei_Texture_SumVariance_GFP_3_03_256  \
# 0                                 0.134600
# 1                                -0.183358
# 2                                -0.274598
# 3                                -0.345926
# 4                                -0.047649
#
#    Nuclei_Texture_SumVariance_RFP_3_03_256
# 0                                -0.251341
# 1                                -0.042808
# 2                                -0.171764
# 3                                -0.356443
# 4                                -0.217650
#
# [5 rows x 1136 columns]

# %% [markdown]
# ### Plate 5

# %%
# Load in plate 3 rpime dataframe
plate5_path = pathlib.Path(f"{root_dir}/../nf1_cellpainting_data/3.processing_features/data/single_cell_profiles/Plate_5_bulk_camerons_method.parquet")
plate5df = pd.read_parquet(plate5_path)

print(plate5df.shape)
plate5df.head()
# Out:
# (48, 1164)
#   Metadata_WellRow  Metadata_WellCol Metadata_Well  \
# 0                B                 1            B1
# 1                B                 2            B2
# 2                B                 3            B3
# 3                B                 4            B4
# 4                B                 9            B9
#
#    Metadata_number_of_singlecells Metadata_gene_name Metadata_genotype  \
# 0                              79                NF1                WT
# 1                              97                NF1                WT
# 2                              79                NF1                WT
# 3                             112                NF1                WT
# 4                             173                NF1              Null
#
#   Metadata_Plate  Cytoplasm_AreaShape_Area  Cytoplasm_AreaShape_Compactness  \
# 0        Plate_5                  0.083938                        -0.066136
# 1        Plate_5                 -0.131937                        -0.206127
# 2        Plate_5                 -0.182499                         0.033284
# 3        Plate_5                  0.481475                        -0.001622
# 4        Plate_5                  0.042459                        -0.381537
#
#    Cytoplasm_AreaShape_Eccentricity  ...  \
# 0                          0.348500  ...
# 1                          0.316345  ...
# 2                          0.217583  ...
# 3                          0.107639  ...
# 4                          0.086107  ...
#
#    Nuclei_Texture_InverseDifferenceMoment_RFP_3_00_256  \
# 0                                          -0.299631
# 1                                          -0.345351
# 2                                          -0.109244
# 3                                          -0.161333
# 4                                          -0.103168
#
#    Nuclei_Texture_InverseDifferenceMoment_RFP_3_01_256  \
# 0                                          -0.081480
# 1                                          -0.459259
# 2                                          -0.067043
# 3                                          -0.128519
# 4                                          -0.022629
#
#    Nuclei_Texture_InverseDifferenceMoment_RFP_3_02_256  \
# 0                                          -0.301456
# 1                                          -0.293587
# 2                                          -0.219248
# 3                                          -0.282394
# 4                                          -0.113879
#
#    Nuclei_Texture_InverseDifferenceMoment_RFP_3_03_256  \
# 0                                          -0.125438
# 1                                          -0.310423
# 2                                          -0.170340
# 3                                          -0.109331
# 4                                          -0.098732
#
#    Nuclei_Texture_SumEntropy_DAPI_3_02_256  \
# 0                                 0.198620
# 1                                 0.436946
# 2                                 0.522507
# 3                                 0.389289
# 4                                 0.445310
#
#    Nuclei_Texture_SumEntropy_RFP_3_01_256  \
# 0                                0.000160
# 1                                0.261724
# 2                               -0.061010
# 3                               -0.113606
# 4                               -0.171365
#
#    Nuclei_Texture_SumVariance_CY5_3_03_256  \
# 0                                -0.574768
# 1                                -0.264806
# 2                                -0.457810
# 3                                -0.558904
# 4                                -0.577611
#
#    Nuclei_Texture_SumVariance_DAPI_3_03_256  \
# 0                                 -0.294731
# 1                                 -0.064707
# 2                                 -0.055988
# 3                                 -0.199895
# 4                                 -0.087306
#
#    Nuclei_Texture_SumVariance_GFP_3_03_256  \
# 0                                -0.258817
# 1                                -0.369254
# 2                                -0.452981
# 3                                -0.501300
# 4                                -0.476644
#
#    Nuclei_Texture_SumVariance_RFP_3_01_256
# 0                                -0.316784
# 1                                -0.236444
# 2                                -0.321178
# 3                                -0.339054
# 4                                -0.341957
#
# [5 rows x 1164 columns]

# %% [markdown]
# ## Concat data and generate correlations

# %%
# List of dataframes
dfs = [plate3df, plate4df, plate3pdf, plate5df]

# Specified metadata columns to keep
metadata_columns = ['Metadata_Plate', 'Metadata_Well', 'Metadata_genotype', 'Metadata_seed_density']

# Find the common feature columns (not starting with 'Metadata')
common_feature_columns = set(dfs[0].columns) - set(metadata_columns)
for df in dfs[1:]:
    common_feature_columns.intersection_update(set(df.columns) - set(metadata_columns))

# Convert to sorted list for consistent ordering
common_feature_columns = sorted(common_feature_columns)

# Create a list of all necessary columns, metadata first
all_columns = metadata_columns + sorted(common_feature_columns)

# Reindex each dataframe to have all necessary columns, filling missing values with NaN
dfs_reindexed = [df.reindex(columns=all_columns, fill_value=pd.NA) for df in dfs]

# Concatenate the dataframes
result = pd.concat(dfs_reindexed, ignore_index=True)

print(result.shape)
result.head()
# Out:
# (159, 860)
#   Metadata_Plate Metadata_Well Metadata_genotype Metadata_seed_density  \
# 0        Plate_3            B1                WT                   500
# 1        Plate_3            B2                WT                  1000
# 2        Plate_3            B3                WT                  2000
# 3        Plate_3            B4                WT                  4000
# 4        Plate_3            B9              Null                   500
#
#    Cells_AreaShape_MedianRadius  Cells_AreaShape_Zernike_2_0  \
# 0                      0.014679                    -0.317731
# 1                      0.570749                    -0.361819
# 2                      0.107733                    -0.055177
# 3                     -0.346284                     0.208626
# 4                      0.436601                    -0.293247
#
#    Cells_AreaShape_Zernike_3_1  Cells_AreaShape_Zernike_4_0  \
# 0                    -0.481998                     0.159338
# 1                    -0.207300                    -0.140704
# 2                    -0.174336                     0.073085
# 3                     0.022589                    -0.240306
# 4                    -0.074100                    -0.176156
#
#    Cells_AreaShape_Zernike_4_2  Cells_AreaShape_Zernike_5_1  ...  \
# 0                    -0.152619                    -0.088000  ...
# 1                    -0.131434                     0.166185  ...
# 2                    -0.038556                    -0.077802  ...
# 3                    -0.058304                    -0.079331  ...
# 4                     0.063355                     0.116358  ...
#
#    Nuclei_Texture_InfoMeas1_RFP_3_02_256  \
# 0                              -0.908469
# 1                               0.356421
# 2                               0.406876
# 3                               0.450849
# 4                              -0.621968
#
#    Nuclei_Texture_InfoMeas2_GFP_3_00_256  \
# 0                               1.033512
# 1                               0.172682
# 2                              -0.223375
# 3                              -0.193052
# 4                               1.081576
#
#    Nuclei_Texture_InfoMeas2_RFP_3_00_256  \
# 0                               0.959132
# 1                               0.068585
# 2                               0.019349
# 3                              -0.132589
# 4                               0.896223
#
#    Nuclei_Texture_InfoMeas2_RFP_3_01_256  \
# 0                               1.040629
# 1                               0.088951
# 2                              -0.082521
# 3                              -0.113166
# 4                               0.887652
#
#    Nuclei_Texture_InfoMeas2_RFP_3_02_256  \
# 0                               0.990250
# 1                               0.048348
# 2                              -0.012171
# 3                               0.002563
# 4                               0.857612
#
#    Nuclei_Texture_InfoMeas2_RFP_3_03_256  \
# 0                               1.022979
# 1                              -0.055821
# 2                              -0.018876
# 3                               0.006693
# 4                               0.940805
#
#    Nuclei_Texture_InverseDifferenceMoment_RFP_3_00_256  \
# 0                                          -0.854267
# 1                                          -0.152886
# 2                                          -0.040054
# 3                                          -0.414899
# 4                                          -0.455060
#
#    Nuclei_Texture_InverseDifferenceMoment_RFP_3_01_256  \
# 0                                          -0.880062
# 1                                          -0.178630
# 2                                          -0.027139
# 3                                          -0.346908
# 4                                          -0.400958
#
#    Nuclei_Texture_InverseDifferenceMoment_RFP_3_02_256  \
# 0                                          -0.599407
# 1                                          -0.072712
# 2                                           0.036813
# 3                                          -0.310155
# 4                                          -0.474513
#
#    Nuclei_Texture_InverseDifferenceMoment_RFP_3_03_256
# 0                                          -0.757853
# 1                                          -0.025244
# 2                                           0.169018
# 3                                          -0.211360
# 4                                          -0.415342
#
# [5 rows x 860 columns]

# %%
# Identify feature columns
feat_cols = [col for col in result.columns if not col.startswith('Metadata')]

result_corr = generate_correlations(df=result, feat_cols=feat_cols)

# Save the concatenated DataFrame as a Parquet file
result_corr.to_parquet('./construct_correlation_data/concatenated_all_plates_correlations.parquet', index=False)

print(result_corr.shape)
result_corr.head()
# Out:
# (12561, 9)
#    correlation Metadata_Well__group0 Metadata_Well__group1  \
# 0    -0.016705                    B1                    B2
# 1    -0.183320                    B1                    B3
# 2    -0.432502                    B1                    B4
# 3     0.532710                    B1                    B9
# 4     0.104033                    B1                   B10
#
#   Metadata_genotype__group0 Metadata_genotype__group1 Metadata_plate__group0  \
# 0                        WT                        WT                Plate_3
# 1                        WT                        WT                Plate_3
# 2                        WT                        WT                Plate_3
# 3                        WT                      Null                Plate_3
# 4                        WT                      Null                Plate_3
#
#   Metadata_plate__group1 Metadata_seed_density__group0  \
# 0                Plate_3                           500
# 1                Plate_3                           500
# 2                Plate_3                           500
# 3                Plate_3                           500
# 4                Plate_3                           500
#
#   Metadata_seed_density__group1
# 0                          1000
# 1                          2000
# 2                          4000
# 3                           500
# 4                          1000
